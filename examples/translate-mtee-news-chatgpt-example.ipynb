# %%
# !git clone https://github.com/taidopurason/llm-mt
# !pip install ./llm-mt
# Out:
# Cloning into 'llm-mt'...
# remote: Enumerating objects: 2830, done.
# remote: Counting objects: 100% (311/311), done.
# remote: Compressing objects: 100% (276/276), done.
# remote: Total 2830 (delta 37), reused 305 (delta 35), pack-reused 2519
# Receiving objects: 100% (2830/2830), 2.14 MiB | 10.34 MiB/s, done.
# Resolving deltas: 100% (151/151), done.
# Processing ./llm-mt
# done
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from llm-mt-eval==0.1.0) (1.23.5)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from llm-mt-eval==0.1.0) (1.5.3)
# Collecting openai (from llm-mt-eval==0.1.0)
#   Downloading openai-0.27.10-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 4.0 MB/s eta 0:00:00
# Collecting tiktoken (from llm-mt-eval==0.1.0)
#   Downloading tiktoken-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 46.4 MB/s eta 0:00:00
# Requirement already satisfied: tenacity in /opt/conda/lib/python3.10/site-packages (from llm-mt-eval==0.1.0) (8.2.2)
# Collecting sacrebleu==2.3.1 (from llm-mt-eval==0.1.0)
#   Downloading sacrebleu-2.3.1-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 9.5 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu==2.3.1->llm-mt-eval==0.1.0)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from sacrebleu==2.3.1->llm-mt-eval==0.1.0) (2023.6.3)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/conda/lib/python3.10/site-packages (from sacrebleu==2.3.1->llm-mt-eval==0.1.0) (0.9.0)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from sacrebleu==2.3.1->llm-mt-eval==0.1.0) (0.4.6)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from sacrebleu==2.3.1->llm-mt-eval==0.1.0) (4.9.3)
# Requirement already satisfied: requests>=2.20 in /opt/conda/lib/python3.10/site-packages (from openai->llm-mt-eval==0.1.0) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from openai->llm-mt-eval==0.1.0) (4.65.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from openai->llm-mt-eval==0.1.0) (3.8.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas->llm-mt-eval==0.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->llm-mt-eval==0.1.0) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->llm-mt-eval==0.1.0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->openai->llm-mt-eval==0.1.0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->openai->llm-mt-eval==0.1.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->openai->llm-mt-eval==0.1.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->openai->llm-mt-eval==0.1.0) (2023.5.7)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai->llm-mt-eval==0.1.0) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai->llm-mt-eval==0.1.0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai->llm-mt-eval==0.1.0) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai->llm-mt-eval==0.1.0) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai->llm-mt-eval==0.1.0) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->openai->llm-mt-eval==0.1.0) (1.3.1)
# Building wheels for collected packages: llm-mt-eval
# done
#   Created wheel for llm-mt-eval: filename=llm_mt_eval-0.1.0-py3-none-any.whl size=5279 sha256=1f9bd541245af51f86506a31abe9cf664ca229a4184b81c94c2fca697542f62f
#   Stored in directory: /root/.cache/pip/wheels/8e/73/fd/e0ac410939d44ea5625f4367c72993699c9426872604613c4d
# Successfully built llm-mt-eval
# Installing collected packages: portalocker, tiktoken, sacrebleu, openai, llm-mt-eval
# Successfully installed llm-mt-eval-0.1.0 openai-0.27.10 portalocker-2.7.0 sacrebleu-2.3.1 tiktoken-0.4.0

# %%
import logging

for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)
    
logging.basicConfig(
    format="%(asctime)s | %(levelname)s | %(name)s | %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
    level=logging.INFO,
)

# %%
import openai
from kaggle_secrets import UserSecretsClient

# For Kaggle notebooks:
user_secrets = UserSecretsClient()
openai.api_key = user_secrets.get_secret("tartunlp_openai")

# For everyone else:
# openai.api_key = os.environ["OPENAI_API_KEY"]

# %%
from llm_mt_eval.utils import read_json
from llm_mt_eval.translate import translate_document_files
from pathlib import Path
from typing import List


language_name_map = {
    "et": "Estonian",
    "en": "English",
    "de": "German",
    "ru": "Russian"
}

lang_pair_doc_names = {
    "et-en": ['doc-1-1.txt', 'doc-1-5.txt', 'doc-1-7.txt', 'doc-2-13.txt', 'doc-2-14.txt', 'doc-2-16.txt', 'doc-2-19.txt', 'doc-2-21.txt', 'doc-2-22.txt', 'doc-2-28.txt', 'doc-3-36.txt', 'doc-3-37.txt', 'doc-3-39.txt', 'doc-3-41.txt', 'doc-3-43.txt', 'doc-3-44.txt', 'doc-3-46.txt', 'doc-3-47.txt', 'doc-3-49.txt', 'doc-3-51.txt', 'doc-3-52.txt', 'doc-3-54.txt', 'doc-3-58.txt', 'doc-3-59.txt', 'doc-3-62.txt', 'doc-3-64.txt', 'doc-3-71.txt', 'doc-3-73.txt', 'doc-3-74.txt', 'doc-3-75.txt', 'doc-3-76.txt', 'doc-3-77.txt', 'doc-3-78.txt', 'doc-3-79.txt', 'doc-4-81.txt', 'doc-4-85.txt', 'doc-4-86.txt', 'doc-4-89.txt', 'doc-4-92.txt', 'doc-4-93.txt', 'doc-4-94.txt', 'doc-4-95.txt', 'doc-5-105.txt', 'doc-5-108.txt', 'doc-5-110.txt'],
    "en-et": ['doc-1-1.txt', 'doc-1-13.txt', 'doc-1-15.txt', 'doc-1-17.txt', 'doc-1-18.txt', 'doc-1-20.txt', 'doc-1-21.txt', 'doc-1-28.txt', 'doc-1-3.txt', 'doc-1-30.txt', 'doc-1-33.txt', 'doc-1-34.txt', 'doc-1-36.txt', 'doc-1-38.txt', 'doc-1-39.txt', 'doc-1-4.txt', 'doc-1-41.txt', 'doc-1-42.txt', 'doc-1-43.txt', 'doc-1-44.txt', 'doc-1-45.txt', 'doc-1-48.txt', 'doc-1-49.txt', 'doc-1-51.txt', 'doc-1-53.txt', 'doc-1-6.txt', 'doc-2-55.txt', 'doc-2-56.txt', 'doc-2-57.txt', 'doc-2-60.txt', 'doc-2-61.txt', 'doc-2-62.txt', 'doc-2-66.txt', 'doc-2-67.txt', 'doc-2-70.txt', 'doc-3-71.txt', 'doc-3-75.txt', 'doc-3-76.txt', 'doc-3-78.txt', 'doc-3-80.txt', 'doc-3-81.txt', 'doc-4-85.txt', 'doc-4-86.txt', 'doc-4-87.txt', 'doc-4-89.txt']
}    
    
for lang_pair in ["et-en"]:
    src, tgt = lang_pair.split("-")
    src_dir = f"llm-mt/data/mtee-news/{src}_src"
    ref_dir = f"llm-mt/data/mtee-news/{lang_pair}_ref"
    src_lang = language_name_map[src]
    tgt_lang = language_name_map[tgt]
    doc_names = lang_pair_doc_names[lang_pair]
    
    print(src_dir, ref_dir, src_lang, tgt_lang)
    print("translated doc names", doc_names)
    
    response_path = f"mtee-news.p2.{lang_pair}.response.json"
    
    translate_document_files(
        src_lang=src_lang,
        tgt_lang=tgt_lang,
        src_dir=src_dir,
        ref_dir=ref_dir,
        doc_names=doc_names,
        prompt="Translate the following {src_lang} text into {tgt_lang}:\n{sentence}",
        response_out_path = response_path,
        hyp_out_dir = f"mtee-news.p2.{lang_pair}_hyps",
        concat_hyp_out_path = f"mtee-news.p2.{lang_pair}.hyp",
        sent_delimiter = "\n",
        metrics = ("bleu", "chrf", "chrf++")
    )
    
    responses = read_json(response_path)
    prompt_tokens = sum([response["usage"]["prompt_tokens"] for response in responses])
    completion_tokens = sum(response["usage"]["completion_tokens"] for response in responses)
    cost = (prompt_tokens * 0.0015 + completion_tokens * 0.002) / 1000
    print("Cost:", cost)
# Out:
# llm-mt/data/mtee-news/et_src llm-mt/data/mtee-news/et-en_ref Estonian English
# translated doc names ['doc-1-1.txt', 'doc-1-5.txt', 'doc-1-7.txt', 'doc-2-13.txt', 'doc-2-14.txt', 'doc-2-16.txt', 'doc-2-19.txt', 'doc-2-21.txt', 'doc-2-22.txt', 'doc-2-28.txt', 'doc-3-36.txt', 'doc-3-37.txt', 'doc-3-39.txt', 'doc-3-41.txt', 'doc-3-43.txt', 'doc-3-44.txt', 'doc-3-46.txt', 'doc-3-47.txt', 'doc-3-49.txt', 'doc-3-51.txt', 'doc-3-52.txt', 'doc-3-54.txt', 'doc-3-58.txt', 'doc-3-59.txt', 'doc-3-62.txt', 'doc-3-64.txt', 'doc-3-71.txt', 'doc-3-73.txt', 'doc-3-74.txt', 'doc-3-75.txt', 'doc-3-76.txt', 'doc-3-77.txt', 'doc-3-78.txt', 'doc-3-79.txt', 'doc-4-81.txt', 'doc-4-85.txt', 'doc-4-86.txt', 'doc-4-89.txt', 'doc-4-92.txt', 'doc-4-93.txt', 'doc-4-94.txt', 'doc-4-95.txt', 'doc-5-105.txt', 'doc-5-108.txt', 'doc-5-110.txt']
#   0%|          | 0/45 [00:00<?, ?it/s]2023-08-31 10:16:15 | INFO | llm_mt_eval.translate | Translating doc-1-1.txt (llm-mt/data/mtee-news/et_src/doc-1-1.txt)
# 2023-08-31 10:16:17 | INFO | llm_mt_eval.translate | translating a request with 1090 tokens
#   2%|▏         | 1/45 [00:20<15:00, 20.46s/it]2023-08-31 10:16:35 | INFO | llm_mt_eval.translate | Translating doc-1-5.txt (llm-mt/data/mtee-news/et_src/doc-1-5.txt)
# 2023-08-31 10:16:35 | INFO | llm_mt_eval.translate | translating a request with 627 tokens
#   4%|▍         | 2/45 [00:30<10:28, 14.62s/it]2023-08-31 10:16:46 | INFO | llm_mt_eval.translate | Translating doc-1-7.txt (llm-mt/data/mtee-news/et_src/doc-1-7.txt)
# 2023-08-31 10:16:46 | INFO | llm_mt_eval.translate | translating a request with 375 tokens
#   7%|▋         | 3/45 [00:38<08:03, 11.52s/it]2023-08-31 10:16:53 | INFO | llm_mt_eval.translate | Translating doc-2-13.txt (llm-mt/data/mtee-news/et_src/doc-2-13.txt)
# 2023-08-31 10:16:53 | INFO | llm_mt_eval.translate | translating a request with 362 tokens
#   9%|▉         | 4/45 [00:46<06:50, 10.01s/it]2023-08-31 10:17:01 | INFO | llm_mt_eval.translate | Translating doc-2-14.txt (llm-mt/data/mtee-news/et_src/doc-2-14.txt)
# 2023-08-31 10:17:01 | INFO | llm_mt_eval.translate | translating a request with 200 tokens
#  11%|█         | 5/45 [00:50<05:15,  7.89s/it]2023-08-31 10:17:05 | INFO | llm_mt_eval.translate | Translating doc-2-16.txt (llm-mt/data/mtee-news/et_src/doc-2-16.txt)
# 2023-08-31 10:17:05 | INFO | llm_mt_eval.translate | translating a request with 383 tokens
#  13%|█▎        | 6/45 [00:57<04:52,  7.51s/it]2023-08-31 10:17:12 | INFO | llm_mt_eval.translate | Translating doc-2-19.txt (llm-mt/data/mtee-news/et_src/doc-2-19.txt)
# 2023-08-31 10:17:12 | INFO | llm_mt_eval.translate | translating a request with 327 tokens
#  16%|█▌        | 7/45 [01:05<04:49,  7.62s/it]2023-08-31 10:17:20 | INFO | llm_mt_eval.translate | Translating doc-2-21.txt (llm-mt/data/mtee-news/et_src/doc-2-21.txt)
# 2023-08-31 10:17:20 | INFO | llm_mt_eval.translate | translating a request with 217 tokens
#  18%|█▊        | 8/45 [01:09<03:58,  6.45s/it]2023-08-31 10:17:24 | INFO | llm_mt_eval.translate | Translating doc-2-22.txt (llm-mt/data/mtee-news/et_src/doc-2-22.txt)
# 2023-08-31 10:17:24 | INFO | llm_mt_eval.translate | translating a request with 250 tokens
#  20%|██        | 9/45 [01:14<03:38,  6.06s/it]2023-08-31 10:17:29 | INFO | llm_mt_eval.translate | Translating doc-2-28.txt (llm-mt/data/mtee-news/et_src/doc-2-28.txt)
# 2023-08-31 10:17:29 | INFO | llm_mt_eval.translate | translating a request with 559 tokens
#  22%|██▏       | 10/45 [01:23<04:03,  6.96s/it]2023-08-31 10:17:38 | INFO | llm_mt_eval.translate | Translating doc-3-36.txt (llm-mt/data/mtee-news/et_src/doc-3-36.txt)
# 2023-08-31 10:17:38 | INFO | llm_mt_eval.translate | translating a request with 508 tokens
#  24%|██▍       | 11/45 [01:35<04:45,  8.39s/it]2023-08-31 10:17:50 | INFO | llm_mt_eval.translate | Translating doc-3-37.txt (llm-mt/data/mtee-news/et_src/doc-3-37.txt)
# 2023-08-31 10:17:50 | INFO | llm_mt_eval.translate | translating a request with 149 tokens
#  27%|██▋       | 12/45 [01:37<03:34,  6.50s/it]2023-08-31 10:17:52 | INFO | llm_mt_eval.translate | Translating doc-3-39.txt (llm-mt/data/mtee-news/et_src/doc-3-39.txt)
# 2023-08-31 10:17:52 | INFO | llm_mt_eval.translate | translating a request with 606 tokens
#  29%|██▉       | 13/45 [01:49<04:28,  8.39s/it]2023-08-31 10:18:05 | INFO | llm_mt_eval.translate | Translating doc-3-41.txt (llm-mt/data/mtee-news/et_src/doc-3-41.txt)
# 2023-08-31 10:18:05 | INFO | llm_mt_eval.translate | translating a request with 575 tokens
#  31%|███       | 14/45 [02:00<04:36,  8.91s/it]2023-08-31 10:18:15 | INFO | llm_mt_eval.translate | Translating doc-3-43.txt (llm-mt/data/mtee-news/et_src/doc-3-43.txt)
# 2023-08-31 10:18:15 | INFO | llm_mt_eval.translate | translating a request with 467 tokens
#  33%|███▎      | 15/45 [02:08<04:22,  8.76s/it]2023-08-31 10:18:23 | INFO | llm_mt_eval.translate | Translating doc-3-44.txt (llm-mt/data/mtee-news/et_src/doc-3-44.txt)
# 2023-08-31 10:18:23 | INFO | llm_mt_eval.translate | translating a request with 636 tokens
#  36%|███▌      | 16/45 [02:19<04:35,  9.51s/it]2023-08-31 10:18:34 | INFO | llm_mt_eval.translate | Translating doc-3-46.txt (llm-mt/data/mtee-news/et_src/doc-3-46.txt)
# 2023-08-31 10:18:34 | INFO | llm_mt_eval.translate | translating a request with 333 tokens
#  38%|███▊      | 17/45 [02:25<03:55,  8.40s/it]2023-08-31 10:18:40 | INFO | llm_mt_eval.translate | Translating doc-3-47.txt (llm-mt/data/mtee-news/et_src/doc-3-47.txt)
# 2023-08-31 10:18:40 | INFO | llm_mt_eval.translate | translating a request with 777 tokens
#  40%|████      | 18/45 [02:39<04:28,  9.94s/it]2023-08-31 10:18:54 | INFO | llm_mt_eval.translate | Translating doc-3-49.txt (llm-mt/data/mtee-news/et_src/doc-3-49.txt)
# 2023-08-31 10:18:54 | INFO | llm_mt_eval.translate | translating a request with 292 tokens
#  42%|████▏     | 19/45 [02:44<03:39,  8.44s/it]2023-08-31 10:18:59 | INFO | llm_mt_eval.translate | Translating doc-3-51.txt (llm-mt/data/mtee-news/et_src/doc-3-51.txt)
# 2023-08-31 10:18:59 | INFO | llm_mt_eval.translate | translating a request with 102 tokens
#  44%|████▍     | 20/45 [02:45<02:41,  6.47s/it]2023-08-31 10:19:00 | INFO | llm_mt_eval.translate | Translating doc-3-52.txt (llm-mt/data/mtee-news/et_src/doc-3-52.txt)
# 2023-08-31 10:19:00 | INFO | llm_mt_eval.translate | translating a request with 844 tokens
#  47%|████▋     | 21/45 [03:00<03:36,  9.01s/it]2023-08-31 10:19:15 | INFO | llm_mt_eval.translate | Translating doc-3-54.txt (llm-mt/data/mtee-news/et_src/doc-3-54.txt)
# 2023-08-31 10:19:15 | INFO | llm_mt_eval.translate | translating a request with 233 tokens
#  49%|████▉     | 22/45 [03:05<02:56,  7.68s/it]2023-08-31 10:19:20 | INFO | llm_mt_eval.translate | Translating doc-3-58.txt (llm-mt/data/mtee-news/et_src/doc-3-58.txt)
# 2023-08-31 10:19:20 | INFO | llm_mt_eval.translate | translating a request with 599 tokens
#  51%|█████     | 23/45 [03:15<03:02,  8.30s/it]2023-08-31 10:19:30 | INFO | llm_mt_eval.translate | Translating doc-3-59.txt (llm-mt/data/mtee-news/et_src/doc-3-59.txt)
# 2023-08-31 10:19:30 | INFO | llm_mt_eval.translate | translating a request with 295 tokens
#  53%|█████▎    | 24/45 [03:20<02:38,  7.55s/it]2023-08-31 10:19:36 | INFO | llm_mt_eval.translate | Translating doc-3-62.txt (llm-mt/data/mtee-news/et_src/doc-3-62.txt)
# 2023-08-31 10:19:36 | INFO | llm_mt_eval.translate | translating a request with 194 tokens
#  56%|█████▌    | 25/45 [03:23<02:02,  6.14s/it]2023-08-31 10:19:38 | INFO | llm_mt_eval.translate | Translating doc-3-64.txt (llm-mt/data/mtee-news/et_src/doc-3-64.txt)
# 2023-08-31 10:19:38 | INFO | llm_mt_eval.translate | translating a request with 816 tokens
#  58%|█████▊    | 26/45 [03:37<02:39,  8.41s/it]2023-08-31 10:19:52 | INFO | llm_mt_eval.translate | Translating doc-3-71.txt (llm-mt/data/mtee-news/et_src/doc-3-71.txt)
# 2023-08-31 10:19:52 | INFO | llm_mt_eval.translate | translating a request with 398 tokens
#  60%|██████    | 27/45 [03:45<02:29,  8.30s/it]2023-08-31 10:20:00 | INFO | llm_mt_eval.translate | Translating doc-3-73.txt (llm-mt/data/mtee-news/et_src/doc-3-73.txt)
# 2023-08-31 10:20:00 | INFO | llm_mt_eval.translate | translating a request with 298 tokens
#  62%|██████▏   | 28/45 [03:50<02:05,  7.41s/it]2023-08-31 10:20:05 | INFO | llm_mt_eval.translate | Translating doc-3-74.txt (llm-mt/data/mtee-news/et_src/doc-3-74.txt)
# 2023-08-31 10:20:05 | INFO | llm_mt_eval.translate | translating a request with 249 tokens
#  64%|██████▍   | 29/45 [03:55<01:44,  6.56s/it]2023-08-31 10:20:10 | INFO | llm_mt_eval.translate | Translating doc-3-75.txt (llm-mt/data/mtee-news/et_src/doc-3-75.txt)
# 2023-08-31 10:20:10 | INFO | llm_mt_eval.translate | translating a request with 816 tokens
#  67%|██████▋   | 30/45 [04:08<02:09,  8.66s/it]2023-08-31 10:20:24 | INFO | llm_mt_eval.translate | Translating doc-3-76.txt (llm-mt/data/mtee-news/et_src/doc-3-76.txt)
# 2023-08-31 10:20:24 | INFO | llm_mt_eval.translate | translating a request with 1112 tokens
#  69%|██████▉   | 31/45 [04:24<02:29, 10.66s/it]2023-08-31 10:20:39 | INFO | llm_mt_eval.translate | Translating doc-3-77.txt (llm-mt/data/mtee-news/et_src/doc-3-77.txt)
# 2023-08-31 10:20:39 | INFO | llm_mt_eval.translate | translating a request with 1179 tokens
#  71%|███████   | 32/45 [04:43<02:50, 13.12s/it]2023-08-31 10:20:58 | INFO | llm_mt_eval.translate | Translating doc-3-78.txt (llm-mt/data/mtee-news/et_src/doc-3-78.txt)
# 2023-08-31 10:20:58 | INFO | llm_mt_eval.translate | translating a request with 461 tokens
#  73%|███████▎  | 33/45 [04:50<02:17, 11.45s/it]2023-08-31 10:21:05 | INFO | llm_mt_eval.translate | Translating doc-3-79.txt (llm-mt/data/mtee-news/et_src/doc-3-79.txt)
# 2023-08-31 10:21:05 | INFO | llm_mt_eval.translate | translating a request with 535 tokens
#  76%|███████▌  | 34/45 [05:00<02:00, 10.96s/it]2023-08-31 10:21:15 | INFO | llm_mt_eval.translate | Translating doc-4-81.txt (llm-mt/data/mtee-news/et_src/doc-4-81.txt)
# 2023-08-31 10:21:15 | INFO | llm_mt_eval.translate | translating a request with 180 tokens
#  78%|███████▊  | 35/45 [05:03<01:26,  8.70s/it]2023-08-31 10:21:19 | INFO | llm_mt_eval.translate | Translating doc-4-85.txt (llm-mt/data/mtee-news/et_src/doc-4-85.txt)
# 2023-08-31 10:21:19 | INFO | llm_mt_eval.translate | translating a request with 663 tokens
#  80%|████████  | 36/45 [05:15<01:25,  9.49s/it]2023-08-31 10:21:30 | INFO | llm_mt_eval.translate | Translating doc-4-86.txt (llm-mt/data/mtee-news/et_src/doc-4-86.txt)
# 2023-08-31 10:21:30 | INFO | llm_mt_eval.translate | translating a request with 914 tokens
#  82%|████████▏ | 37/45 [05:30<01:30, 11.27s/it]2023-08-31 10:21:45 | INFO | llm_mt_eval.translate | Translating doc-4-89.txt (llm-mt/data/mtee-news/et_src/doc-4-89.txt)
# 2023-08-31 10:21:45 | INFO | llm_mt_eval.translate | translating a request with 1168 tokens
#  84%|████████▍ | 38/45 [05:48<01:32, 13.18s/it]2023-08-31 10:22:03 | INFO | llm_mt_eval.translate | Translating doc-4-92.txt (llm-mt/data/mtee-news/et_src/doc-4-92.txt)
# 2023-08-31 10:22:03 | INFO | llm_mt_eval.translate | translating a request with 1263 tokens
#  87%|████████▋ | 39/45 [06:08<01:32, 15.33s/it]2023-08-31 10:22:23 | INFO | llm_mt_eval.translate | Translating doc-4-93.txt (llm-mt/data/mtee-news/et_src/doc-4-93.txt)
# 2023-08-31 10:22:23 | INFO | llm_mt_eval.translate | translating a request with 757 tokens
#  89%|████████▉ | 40/45 [06:19<01:09, 13.97s/it]2023-08-31 10:22:34 | INFO | llm_mt_eval.translate | Translating doc-4-94.txt (llm-mt/data/mtee-news/et_src/doc-4-94.txt)
# 2023-08-31 10:22:34 | INFO | llm_mt_eval.translate | translating a request with 867 tokens
#  91%|█████████ | 41/45 [06:33<00:56, 14.12s/it]2023-08-31 10:22:49 | INFO | llm_mt_eval.translate | Translating doc-4-95.txt (llm-mt/data/mtee-news/et_src/doc-4-95.txt)
# 2023-08-31 10:22:49 | INFO | llm_mt_eval.translate | translating a request with 1652 tokens
#  93%|█████████▎| 42/45 [07:00<00:53, 17.70s/it]2023-08-31 10:23:15 | INFO | llm_mt_eval.translate | Translating doc-5-105.txt (llm-mt/data/mtee-news/et_src/doc-5-105.txt)
# 2023-08-31 10:23:15 | INFO | llm_mt_eval.translate | translating a request with 519 tokens
#  96%|█████████▌| 43/45 [07:08<00:30, 15.08s/it]2023-08-31 10:23:24 | INFO | llm_mt_eval.translate | Translating doc-5-108.txt (llm-mt/data/mtee-news/et_src/doc-5-108.txt)
# 2023-08-31 10:23:24 | INFO | llm_mt_eval.translate | translating a request with 589 tokens
#  98%|█████████▊| 44/45 [07:19<00:13, 13.60s/it]2023-08-31 10:23:34 | INFO | llm_mt_eval.translate | Translating doc-5-110.txt (llm-mt/data/mtee-news/et_src/doc-5-110.txt)
# 2023-08-31 10:23:34 | INFO | llm_mt_eval.translate | translating a request with 625 tokens
# 100%|██████████| 45/45 [07:30<00:00, 10.01s/it]
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.translate | prompt tokens: 26376, completion tokens: 14476
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.utils | hyp contains multiple lines, concatenating
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.evaluate | nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.3.1
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.evaluate | bleu score: 31.54
# 2023-08-31 10:23:45 | INFO | root | dbleu: 31.54
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.evaluate | nrefs:1|case:mixed|eff:yes|nc:6|nw:0|space:no|version:2.3.1
# 2023-08-31 10:23:45 | INFO | llm_mt_eval.evaluate | chrf score: 64.33
# 2023-08-31 10:23:45 | INFO | root | dchrf: 64.33
# 2023-08-31 10:23:46 | INFO | llm_mt_eval.evaluate | nrefs:1|case:mixed|eff:yes|nc:6|nw:2|space:no|version:2.3.1
# 2023-08-31 10:23:46 | INFO | llm_mt_eval.evaluate | chrf++ score: 61.71
# 2023-08-31 10:23:46 | INFO | root | dchrf++: 61.71
# Cost: 0.06851600000000001
